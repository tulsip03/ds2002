# %% [markdown]
# <a href="https://colab.research.google.com/github/tulsip03/ds2002/blob/main/VisHomework2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files


uploaded = files.upload()

import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('Top_Highest_Openings.csv')
print(df)
# Out:
#      <input type="file" id="files-d30f779e-33e3-45a5-8dac-dc8d3b4f088b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d30f779e-33e3-45a5-8dac-dc8d3b4f088b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# bar graph showing movie title and average income per theatre
category_column = 'Release'
value_column = 'Average'
categories = df[category_column]
values = df[value_column]

plt.bar(categories, values)

plt.title('Income per Theatre')
plt.xlabel('Movie Title')
plt.ylabel('Average Income')

plt.show()

# %%
x_column = '% of Total'
y_column = 'Opening'
x_values = df[x_column]
y_values = df[y_column]

plt.scatter(x_values, y_values)

plt.title('Scatter Plot Example')
plt.xlabel('Percent of Total Gross Earnings')
plt.ylabel('Opening Weekend Income')

plt.show()

# %%
plot_1 = 'Total Gross'
plot_2 = 'Opening'
data1 = df[plot_1]
data2 = df[plot_2]

plt.boxplot(data1, positions=[1], widths=0.6, patch_artist=True, boxprops=dict(facecolor='skyblue'), medianprops=dict(color='orange'))
plt.boxplot(data2, positions=[2], widths=0.6, patch_artist=True, boxprops=dict(facecolor='lightgreen'), medianprops=dict(color='orange'))

plt.boxplot(data)

plt.title('Total Gross Income vs. Opening Day Income')
plt.ylabel('Income')
plt.xticks([1, 2], ['Total Gross', 'Opening Day'])
# Out:
# ([<matplotlib.axis.XTick at 0x7d7631f2fbe0>,
# ...
#  [Text(1, 0, 'Total Gross'), Text(2, 0, 'Opening Day')])
